# %%
import sys
import os


project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

from Game_Runner import SnakeGameRunner
from Main.Config import BOARD_SIZE

SnakeGameRunner(mode='manual', board_size=BOARD_SIZE).run()
# Out:
# c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Network\single_ai.py:73: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   s = torch.tensor(s, dtype=torch.float32).to(device)
# Step: 1000 | Eps: 0.606
# Step: 2000 | Eps: 0.368
# Step: 3000 | Eps: 0.223
# Step: 4000 | Eps: 0.135
# Step: 5000 | Eps: 0.082
# Step: 6000 | Eps: 0.050
# Step: 7000 | Eps: 0.050
# Step: 8000 | Eps: 0.050
# Step: 9000 | Eps: 0.050
# Step: 10000 | Eps: 0.050
# Step: 11000 | Eps: 0.050
# Step: 12000 | Eps: 0.050
# Step: 13000 | Eps: 0.050
# Step: 14000 | Eps: 0.050
# Step: 15000 | Eps: 0.050
# Step: 16000 | Eps: 0.050
# Step: 17000 | Eps: 0.050
# Step: 18000 | Eps: 0.050
# Step: 19000 | Eps: 0.050
# Step: 20000 | Eps: 0.050
# Step: 21000 | Eps: 0.050
# Step: 22000 | Eps: 0.050
# Step: 23000 | Eps: 0.050
# Step: 24000 | Eps: 0.050
# Step: 25000 | Eps: 0.050
# Step: 26000 | Eps: 0.050
# Step: 27000 | Eps: 0.050
# Step: 28000 | Eps: 0.050
# Step: 29000 | Eps: 0.050
# Step: 30000 | Eps: 0.050
# Step: 31000 | Eps: 0.050
# Step: 32000 | Eps: 0.050
# Step: 33000 | Eps: 0.050
# Step: 34000 | Eps: 0.050
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 12
#       9 from Game_Runner import SnakeGameRunner
#      10 from Main.Config import BOARD_SIZE
# ---> 12 SnakeGameRunner(mode='model', board_size=BOARD_SIZE).run()
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Main\Game_Runner.py:155, in SnakeGameRunner.run(self)
#     153 self.setup_gui()
#     154 if self.mode == 'model':
# --> 155     self.run_model()
#     156 else:
#     157     self.run_manual()
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Main\Game_Runner.py:142, in SnakeGameRunner.run_model(self)
#     139         self.root.update()
#     141 tk.Button(self.root, text="Reset", command=self.game.reset).pack()
# --> 142 loop()
#     143 self.root.mainloop()
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Main\Game_Runner.py:118, in SnakeGameRunner.run_model.<locals>.loop()
#     116 def loop():
#     117     while True:
# --> 118         reward = self.model.step_and_train(self.game, self.reward_manager)
#     120         if not self.game.alive():
#     121             self.total_apples += self.game.length() - 3
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Network\single_ai.py:38, in SingleAI.step_and_train(self, game, reward_manager)
#      35 prev_len = game.length()
#      36 reward_manager.update_distance(game.head(), game.apple())
# ---> 38 game.step(direction)
#      40 if game.length() > prev_len:
#      41     reward_manager.ate_apple()
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Game\snake_game.py:21, in SnakeGame.step(self, direction)
#      19 if direction is not None:
#      20     self.gs.set_direction(direction)
# ---> 21 self.gs.step()
#
# File c:\Users\Tyler\python_code\Final_Project\Snake Real\SnakeV2\Game\game_state.py:91, in GameState.step(self)
#      89     tail_y, tail_x = self.snake.pop()
#      90     if self.render:
# ---> 91         self.tiles[tail_y][tail_x].delete("all")
#      93 self.redraw_head_and_neck()
#
# File c:\Users\Tyler\anaconda3\envs\LHL_Env\lib\tkinter\__init__.py:2823, in Canvas.delete(self, *args)
#    2821 def delete(self, *args):
#    2822     """Delete items identified by all tag or ids contained in ARGS."""
# -> 2823     self.tk.call((self._w, 'delete') + args)
#
# TclError: invalid command name ".!canvas.!frame.!canvas54"
