# %%
from main import run_snake_game

# %%
if __name__ == "__main__":
    run_snake_game(False)
# Out:
# [DEBUG] Background thread started
# [DEBUG] Generation 1 using pop_size 50
# c:\Users\Tyler\anaconda3\envs\LHL_Env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [DEBUG] Generation 1 starting with step_limit 40...
# [DEBUG] run_model done with score: 17.4
# [DEBUG] run_model done with score: 12.600000000000001
# Game Over
# [DEBUG] run_model done with score: 4.3
# [DEBUG] run_model done with score: 12.8
# Game Over
# [DEBUG] run_model done with score: 10.1
# Game Over
# [DEBUG] run_model done with score: 4.699999999999999
# [DEBUG] run_model done with score: 14.399999999999999
# Game Over
# [DEBUG] run_model done with score: 4.8999999999999995
# [DEBUG] run_model done with score: 12.8
# ...
