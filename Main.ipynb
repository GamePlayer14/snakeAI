# %%
from main import run_snake_game

# %%
if __name__ == "__main__":
    run_snake_game(False)
# Out:
# [DEBUG] Background thread started
# [DEBUG] Generation 1 using pop_size 20
# [DEBUG] Generation 1 starting with step_limit 100...
# [DEBUG] Generation step - head: (20, 21), steps: 1, generation: 1
# [DEBUG] Generation step - head: (19, 21), steps: 2, generation: 1
# [DEBUG] Generation step - head: (19, 20), steps: 3, generation: 1
# [DEBUG] Generation step - head: (20, 20), steps: 4, generation: 1
# [DEBUG] Generation step - head: (20, 21), steps: 5, generation: 1
# [DEBUG] Generation step - head: (19, 21), steps: 6, generation: 1
# [DEBUG] Generation step - head: (19, 20), steps: 7, generation: 1
# [DEBUG] Generation step - head: (20, 20), steps: 8, generation: 1
# [DEBUG] Generation step - head: (20, 21), steps: 9, generation: 1
# [DEBUG] Generation step - head: (19, 21), steps: 10, generation: 1
# [DEBUG] Generation step - head: (19, 20), steps: 11, generation: 1
# [DEBUG] Generation step - head: (20, 20), steps: 12, generation: 1
# ...
