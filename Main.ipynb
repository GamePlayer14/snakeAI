# %%
from main import run_snake_game

# %%
if __name__ == "__main__":
    run_snake_game(False, (20,20))
# Out:
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Game Over
# Generation 1 | Best Score: -4.6
# Game Over
# ...
